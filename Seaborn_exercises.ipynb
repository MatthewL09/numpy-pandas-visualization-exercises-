# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pydataset import data

# %%
iris = sns.load_dataset('iris')

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
def max_value(df):
    length = df[(df.species == 'setosa') | (df.species == 'virginica')].petal_length.max()
    return length

# %%
max_value(iris)
# Out:
# 6.9

# %%
max(iris)
# Out:
# 'species'

# %%
iris.petal_length

iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(x = 'species', y = 'petal_length', data = iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.histplot(iris.petal_length, kde = True)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
#petal length and petal width correlation?

sns.jointplot(data = iris, x = 'petal_length', y = 'petal_width', hue = 'species')

# %%
#Would it be reasonable to predict species based on sepal 
#width and sepal length?  For this, you'll visualize two numeric columns 
#through the lense of a categorical column.


sns.relplot(data= iris, y = 'sepal_width', x ='sepal_length', hue = 'species')

# %%
sns.boxplot(y= 'sepal_length', x = 'species', data = iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.pairplot(data =iris, hue ='species')

# %%
#which features would be best
# petal length and petal width
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
a = sns.load_dataset('anscombe')

a.head()

a.groupby('dataset').describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
sns.relplot(data = a, x ='x', y='y', col ='dataset')

# %%
sns.lmplot(data = a , x ='x', y ='y', col = 'dataset')

# %%
insect = data('InsectSprays')

data('InsectSprays', show_doc = True)
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
# ...

# %%
sns.boxplot(data = insect, y = 'count', x = 'spray')
# Out:
# <AxesSubplot:xlabel='spray', ylabel='count'>

# %%
insect.head()
# Out:
#    count spray
# 1     10     A
# 2      7     A
# 3     20     A
# 4     14     A
# 5     14     A

# %%
swiss = data('swiss')

data('swiss', show_doc = True)

swiss.head()
# Out:
# swiss
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Swiss Fertility and Socioeconomic Indicators (1888) Data
#
# ### Description
#
# Standardized fertility measure and socio-economic indicators for each of 47
# French-speaking provinces of Switzerland at about 1888.
#
# ### Usage
#
#     data(swiss)
#
# ### Format
#
# A data frame with 47 observations on 6 variables, each of which is in percent,
# i.e., in [0,100].
#
# [,1] Fertility Ig, "common standardized fertility measure" [,2] Agriculture
# [,3] Examination nation [,4] Education [,5] Catholic [,6] Infant.Mortality
# live births who live less than 1 year.
#
# All variables but 'Fert' give proportions of the population.
#
# ### Source
#
# Project "16P5", pages 549-551 in
#
# Mosteller, F. and Tukey, J. W. (1977) “Data Analysis and Regression: A Second
# Course in Statistics”. Addison-Wesley, Reading Mass.
#
# ...

# %%
swiss['is_catholic'] = swiss.Catholic > 50

swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# Moutier                   20.3        False
# Neuveville                20.6        False

# %%
sns.relplot(data = swiss, x='Catholic', y ='Fertility', hue ='is_catholic')

# %%
#swiss.iloc[:, :-1]

sns.pairplot(data = swiss)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     350     try:
# --> 351         dt = signed_to_unsigned[dt.type]
#     352     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /var/folders/dy/6l70n7994h596yst0fdjbly40000gn/T/ipykernel_42730/2209935637.py in <module>
#       1 #swiss.iloc[:, :-1]
#       2
# ----> 3 sns.pairplot(data = swiss)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
# ...

# %%
swiss.corr().Fertility
# Out:
# Fertility           1.000000
# Agriculture         0.353079
# Examination        -0.645883
# Education          -0.663789
# Catholic            0.463685
# Infant.Mortality    0.416556
# is_catholic         0.402813
# Name: Fertility, dtype: float64

# %%
chipotle = data('chipotle')
# Out:
# Did you mean:
# Chile, Chirot, Cowles, hirose, cities, Hitters, shuttle, pottery, Pottery, alcohol, coleman

# %%
best_sellers = orders.groupby('item_name').quantity.sum().nlargest(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dy/6l70n7994h596yst0fdjbly40000gn/T/ipykernel_42730/218897646.py in <module>
# ----> 1 best_sellers = orders.groupby('item_name').quantity.sum().nlargest(4)
#
# NameError: name 'orders' is not defined

# %%
revenue = orders[orders.item_name.isin(best_sellers.index)].groupby('item_name').item_price.sum()
revenue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dy/6l70n7994h596yst0fdjbly40000gn/T/ipykernel_42730/1635535665.py in <module>
# ----> 1 revenue = orders[orders.item_name.isin(best_sellers.index)].groupby('item_name').item_price.sum()
#       2 revenue
#
# NameError: name 'orders' is not defined

# %%
# reset_index = allows a new index/column so its easier to plotorders.groupby('item_name')

# %%
sleepstudy = data('sleepstudy')
sleepstudy['Subject'] = 'Subject_' + sleepstudy.Subject.astype(str)

# %%
sleepstudy.head()
# Out:
#    Reaction  Days      Subject
# 1  249.5600     0  Subject_308
# 2  258.7047     1  Subject_308
# 3  250.8006     2  Subject_308
# 4  321.4398     3  Subject_308
# 5  356.8519     4  Subject_308

# %%
plt.figure(figsize =(16,9))

#legend = False
